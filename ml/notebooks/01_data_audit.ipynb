# %%
import pandas as pd
import numpy as np

DATA_PATH = "../../data/raw/invoice_data.csv"

df = pd.read_csv(DATA_PATH)

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (50000, 19)
#
# Columns:
# ['business_code', 'cust_number', 'name_customer', 'clear_date', 'buisness_year', 'doc_id', 'posting_date', 'document_create_date', 'document_create_date.1', 'due_in_date', 'invoice_currency', 'document type', 'posting_id', 'area_business', 'total_open_amount', 'baseline_create_date', 'cust_payment_terms', 'invoice_id', 'isOpen']

# %%
df.head()
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1          U001  0200980828              BEN E   2019-08-08 00:00:00
# 2          U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3          CA02  0140105686            SYSC llc                  NaN
# 4          U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2020.0  1.930438e+09   2020-01-26              20200125
# 1         2019.0  1.929646e+09   2019-07-22              20190722
# 2         2019.0  1.929874e+09   2019-09-14              20190914
# 3         2020.0  2.960623e+09   2020-03-30              20200330
# 4         2019.0  1.930148e+09   2019-11-13              20191113
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200126   20200210.0              USD            RV
# 1                20190722   20190811.0              USD            RV
# 2                20190914   20190929.0              USD            RV
# 3                20200330   20200410.0              CAD            RV
# 4                20191113   20191128.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN           54273.28            20200126.0
# 1         1.0            NaN           79656.60            20190722.0
# 2         1.0            NaN            2253.86            20190914.0
# 3         1.0            NaN            3299.70            20200331.0
# 4         1.0            NaN           33133.29            20191113.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAH4  1.930438e+09       0
# 1               NAD1  1.929646e+09       0
# 2               NAA8  1.929874e+09       0
# 3               CA10  2.960623e+09       1
# 4               NAH4  1.930148e+09       0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  str
#  1   cust_number             50000 non-null  str
#  2   name_customer           50000 non-null  str
#  3   clear_date              40000 non-null  str
#  4   buisness_year           50000 non-null  float64
#  5   doc_id                  50000 non-null  float64
#  6   posting_date            50000 non-null  str
#  7   document_create_date    50000 non-null  int64
#  8   document_create_date.1  50000 non-null  int64
#  9   due_in_date             50000 non-null  float64
#  10  invoice_currency        50000 non-null  str
#  11  document type           50000 non-null  str
#  12  posting_id              50000 non-null  float64
#  13  area_business           0 non-null      float64
#  14  total_open_amount       50000 non-null  float64
#  15  baseline_create_date    50000 non-null  float64
#  16  cust_payment_terms      50000 non-null  str
#  17  invoice_id              49994 non-null  float64
#  18  isOpen                  50000 non-null  int64
# dtypes: float64(8), int64(3), str(8)
# memory usage: 7.2 MB

# %%
missing = pd.DataFrame({
    "missing_count": df.isnull().sum(),
    "missing_percent": df.isnull().mean() * 100
})

missing = missing.sort_values(
    "missing_percent",
    ascending=False
)

missing
# Out:
#                         missing_count  missing_percent
# area_business                   50000          100.000
# clear_date                      10000           20.000
# invoice_id                          6            0.012
# business_code                       0            0.000
# invoice_currency                    0            0.000
# cust_payment_terms                  0            0.000
# baseline_create_date                0            0.000
# total_open_amount                   0            0.000
# posting_id                          0            0.000
# document type                       0            0.000
# due_in_date                         0            0.000
# cust_number                         0            0.000
# document_create_date.1              0            0.000
# document_create_date                0            0.000
# posting_date                        0            0.000
# doc_id                              0            0.000
# buisness_year                       0            0.000
# name_customer                       0            0.000
# isOpen                              0            0.000

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 1161

# %%
if "invoice_id" in df.columns:
    print("Duplicate invoice_id:", df["invoice_id"].duplicated().sum())
# Out:
# Duplicate invoice_id: 1166

# %%
df.describe(include="all").T
# Out:
#                           count unique                  top   freq  \
# business_code             50000      6                 U001  45359
# cust_number               50000   1425           0200769623  11483
# name_customer             50000   4197        WAL-MAR trust   1179
# clear_date                40000    403  2019-11-12 00:00:00    309
# buisness_year           50000.0    NaN                  NaN    NaN
# doc_id                  50000.0    NaN                  NaN    NaN
# posting_date              50000    506           2020-03-24    226
# document_create_date    50000.0    NaN                  NaN    NaN
# document_create_date.1  50000.0    NaN                  NaN    NaN
# due_in_date             50000.0    NaN                  NaN    NaN
# invoice_currency          50000      2                  USD  46081
# document type             50000      2                   RV  49994
# posting_id              50000.0    NaN                  NaN    NaN
# area_business               0.0    NaN                  NaN    NaN
# total_open_amount       50000.0    NaN                  NaN    NaN
# baseline_create_date    50000.0    NaN                  NaN    NaN
# cust_payment_terms        50000     74                 NAA8  20118
# invoice_id              49994.0    NaN                  NaN    NaN
# isOpen                  50000.0    NaN                  NaN    NaN
#
#                                      mean               std           min  \
# business_code                         NaN               NaN           NaN
# cust_number                           NaN               NaN           NaN
# name_customer                         NaN               NaN           NaN
# clear_date                            NaN               NaN           NaN
# buisness_year                   2019.3057          0.460708        2019.0
# doc_id                   2012238145.97236  288523548.906579  1928501756.0
# posting_date                          NaN               NaN           NaN
# document_create_date       20193514.40706       4496.041462    20181226.0
# document_create_date.1     20193537.96784       4482.133787    20181230.0
# due_in_date                20193679.29496       4470.613999    20181224.0
# invoice_currency                      NaN               NaN           NaN
# document type                         NaN               NaN           NaN
# posting_id                            1.0               0.0           1.0
# area_business                         NaN               NaN           NaN
# total_open_amount            32337.021651      39205.975231          0.72
# baseline_create_date        20193539.9285       4482.701432    20181214.0
# cust_payment_terms                    NaN               NaN           NaN
# invoice_id              2011339506.701304  276633494.115106  1928501756.0
# isOpen                                0.2          0.400004           0.0
#
#                                  25%           50%            75%  \
# business_code                    NaN           NaN            NaN
# cust_number                      NaN           NaN            NaN
# name_customer                    NaN           NaN            NaN
# clear_date                       NaN           NaN            NaN
# buisness_year                 2019.0        2019.0         2020.0
# doc_id                  1929342131.5  1929963919.5  1930618818.25
# posting_date                     NaN           NaN            NaN
# document_create_date      20190505.0    20190908.0     20200130.0
# document_create_date.1    20190506.0    20190909.0     20200131.0
# due_in_date               20190524.0    20190926.0     20200216.0
# invoice_currency                 NaN           NaN            NaN
# document type                    NaN           NaN            NaN
# posting_id                       1.0           1.0            1.0
# area_business                    NaN           NaN            NaN
# total_open_amount          4928.3125      17609.01      47133.635
# baseline_create_date      20190505.0    20190909.0     20200131.0
# cust_payment_terms               NaN           NaN            NaN
# invoice_id              1929342050.5  1929963780.5   1930618752.5
# isOpen                           0.0           0.0            0.0
#
#                                  max
# business_code                    NaN
# cust_number                      NaN
# name_customer                    NaN
# clear_date                       NaN
# buisness_year                 2020.0
# doc_id                  9500000133.0
# posting_date                     NaN
# document_create_date      20200522.0
# document_create_date.1    20200522.0
# due_in_date               20200710.0
# invoice_currency                 NaN
# document type                    NaN
# posting_id                       1.0
# area_business                    NaN
# total_open_amount          668593.36
# baseline_create_date      20200522.0
# cust_payment_terms               NaN
# invoice_id              2960635652.0
# isOpen                           1.0

# %%
date_columns = [
    "posting_date",
    "due_in_date",
    "clear_date"
]

for col in date_columns:
    if col in df.columns:
        print(f"\n===== {col} =====")
        print("dtype:", df[col].dtype)
        print("missing:", df[col].isna().sum())
        print("min:", df[col].min())
        print("max:", df[col].max())
# Out:
# ===== posting_date =====
# dtype: str
# missing: 0
# min: 2018-12-30
# max: 2020-05-22
#
# ===== due_in_date =====
# dtype: float64
# missing: 0
# min: 20181224.0
# max: 20200710.0
#
# ===== clear_date =====
# dtype: str
# missing: 10000
# min: 2019-01-03 00:00:00
# max: 2020-05-22 00:00:00

# %%
print("===== DATASET SUMMARY =====")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Duplicate rows:", df.duplicated().sum())
print("Total missing values:", df.isnull().sum().sum())
# Out:
# ===== DATASET SUMMARY =====
# Rows: 50000
# Columns: 19
# Duplicate rows: 1161
# Total missing values: 60006
